# %%
# %cd drive/MyDrive/Colab\ Notebooks/IndustrialClassification
# Out:
# /content/drive/MyDrive/Colab Notebooks/IndustrialClassification

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   .gitignore
# 	new file:   data/ind_class.csv
# 	new file:   data/pre_toks_220321.csv
# 	new file:   data/pre_toks_220321_2.csv
# 	new file:   data/pre_toks_220321_3.csv
# 	new file:   data/pre_toks_220321_4.csv
# 	new file:   data/pre_toks_220322_1.csv
# 	new file:   data/pre_toks_220322_2.csv
# 	new file:   data/pre_toks_220323_2.csv
# 	modified:   git_industrial_classification.ipynb

# %%
# !git add .

# %%
# !git config --global user.email "bwade9090@gmail.com"
# !git config --global user.name "bwade9090"

# %%
# !git commit -m "do not ignore pre_toks.csv"
# Out:
# [main 8088819] do not ignore pre_toks.csv
#  10 files changed, 16446 insertions(+), 2 deletions(-)
#  create mode 100644 data/ind_class.csv
#  create mode 100644 data/pre_toks_220321.csv
#  create mode 100644 data/pre_toks_220321_2.csv
#  create mode 100644 data/pre_toks_220321_3.csv
#  create mode 100644 data/pre_toks_220321_4.csv
#  create mode 100644 data/pre_toks_220322_1.csv
#  create mode 100644 data/pre_toks_220322_2.csv
#  create mode 100644 data/pre_toks_220323_2.csv
#  rewrite git_industrial_classification.ipynb (83%)

# %%
# !git branch -M main

# %%
# !git remote set-url origin https://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@github.com/bwade9090/IndustrialClassification.git

# %%
# !git push -u origin main
# Out:
# Counting objects: 13, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (13/13), 45.22 KiB | 2.66 MiB/s, done.
# Total 13 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 1 local object.
# To https://github.com/bwade9090/IndustrialClassification.git
#    6b38c87..8088819  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
with open('.gitignore', 'w') as f:
  f.write('./data/dataset.csv')
  f.write('./data/testset.csv')
